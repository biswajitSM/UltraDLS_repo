# %%
#Import modules #Run this once

import numpy as np
import pandas as pd
import os.path
from pylab import *
import glob
import os
import re
from xlwt import Workbook
from scipy.optimize import curve_fit
global pointnumber
from numpy import sqrt, pi, exp, linspace, loadtxt
from lmfit import  Model, Parameter, Parameters
import matplotlib.pyplot as plt

# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
# !python read_trc.py
# %run read_trc.py
# !python autocorrelate.py
# %run autocorrelate.py

# %%
def trc_plot(trc_file):
    x, y, d = readTrc(trc_file)
    x=x-min(x)
    avg=average(y)
    No_point = len(x)/10000;
    No_point = int(No_point)
    j=0
    x_avg = []; y_avg=[]
    for i in range(No_point):
        x_avg_temp = average(x[i*1000:1000*(i+1)])
        y_avg_temp = average(y[i*1000:1000*(i+1)])
        j += i
        x_avg = append(x_avg, x_avg_temp)
        y_avg = append(y_avg, y_avg_temp)
    fig, axes = plt.subplots(3,1, figsize=(10, 5))
    axes[0].plot(x,y)
    axes[1].plot(x_avg, y_avg, label=round(average(y_avg),3))
    axes[1].legend()
    G = autocorrelate(y_avg, deltat=4e-10,normalize=True)
    axes[2].plot(G[:,0], G[:,1])
    axes[2].set_xscale('log')
    return

# %% [markdown]
# You can get the files from:
#
# //data02.physics.leidenuniv.nl/datalv/pi-orrit/shared/Oscilloscope

# %% [markdown]
# ## Nanorod

# %%
trc_nr = '/home/biswajit/Downloads/temp/C1eom-1Hz-l_4-pm-1V-00005.trc';
trc_plot(trc_file=trc_nr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-2f72b19b5679> in <module>()
#       1 trc_nr = '/home/biswajit/Downloads/temp/C1eom-1Hz-l_4-pm-1V-00005.trc';
# ----> 2 trc_plot(trc_file=trc_nr)
#
# <ipython-input-7-07a1479dbd6d> in trc_plot(trc_file)
#      17     axes[1].plot(x_avg, y_avg, label=round(average(y_avg),3))
#      18     axes[1].legend()
# ---> 19     G = autocorrelate(y_avg, deltat=4e-10,normalize=True)
#      20     axes[2].plot(G[:,0], G[:,1])
#      21     axes[2].set_xscale('log')
#
# /home/biswajit/Research/Reports_ppt/reports/UltraDLS/UltraDLS_repo/20160804_oscilloscope_test/autocorrelate.py in autocorrelate(a, m, deltat, normalize, copy, dtype)
#      70
#      71     if dtype is None:
# ---> 72         dtype = np.dtype(a[0].__class__)
#      73     else:
#      74         dtype = np.dtype(dtype)
#
# NameError: name 'np' is not defined

# %% [markdown]
# ## Background

# %%
trc_bg = '/home/biswajit/Downloads/temp/C1eom-1Hz-l_4-pm-1V-background00005.trc';
trc_plot(trc_file=trc_bg)
